# %%
import numpy as np

processed_maps = np.load(r'C:/Users/hmc2020/Desktop/kari-onestop-uas/physics_network/processed_data/input_met.npz')
processed_met = np.load(r'C:/Users/hmc2020/Desktop/kari-onestop-uas/physics_network/processed_data/input_maps.npz', allow_pickle=True)
processed_labels_conc = np.load(r'C:/Users/hmc2020/Desktop/kari-onestop-uas/physics_network/processed_data/labels_conc.npz')

print(processed_maps.files)
print(processed_met.files)
print(processed_labels_conc.files)
print('\n')

print('processed maps')
print(processed_maps[processed_maps.files[0]].shape) 
print(processed_maps[processed_maps.files[1]])
print(processed_maps[processed_maps.files[2]])
print('\n')

print('processed met')
print(processed_met[processed_met.files[0]].shape); print(processed_met[processed_met.files[1]].shape)
print(processed_met[processed_met.files[2]].shape); print(processed_met[processed_met.files[3]])
print(processed_met[processed_met.files[4]].shape)
print('\n')

print('processed lablels conc')
print(processed_labels_conc[processed_labels_conc.files[0]].shape); print(processed_labels_conc[processed_labels_conc.files[1]])
# Out:
# ['met', 'max_uv', 'max_L']
# ['terrain', 'source_q', 'source_h', 'terrain_max', 'raw_sources']
# ['conc', 'max_stat']
#
#
# processed maps
# (7103, 43)
# 15.574943
# 1.0
#
#
# processed met
# (45, 45)
# (45, 45)
# (45, 45)
# 95.3
# (10, 4)
#
#
# processed lablels conc
# (7103, 45, 45, 21)
# 9.859336

# %%
a = 3
a
# Out:
# 3
